# %% [markdown]
# <a href="https://colab.research.google.com/github/paab06/Concurrencia/blob/main/Assignment4/course_materials/notebooks/Task01_puzzle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Code to order**

# %%
pip install rdflib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.4/615.4 kB 10.7 MB/s eta 0:00:00
# ...

# %%
github_storage = "https://raw.githubusercontent.com/FacultadInformatica-LinkedData/Curso2026-2027/refs/heads/master/Assignment4/course_materials"

# %%
from rdflib import Graph, Namespace, Literal
g = Graph()

# %%
g.parse(github_storage+"/rdf/example1.rdf", format="xml")
# Out:
# <Graph identifier=Nfc2168ada8f0445ab573b187150a91d2 (<class 'rdflib.graph.Graph'>)>

# %%
g.parse(github_storage+"/rdf/example2.rdf", format="xml")
# Out:
# <Graph identifier=Nfc2168ada8f0445ab573b187150a91d2 (<class 'rdflib.graph.Graph'>)>

# %%
for subj, pred, obj in g:
  print(subj,pred,obj)
# Out:
# http://somewhere/JohnSmith http://www.w3.org/2001/vcard-rdf/3.0#FN John Smith
# http://somewhere/MattJones http://www.w3.org/2001/vcard-rdf/3.0#Given Matt
# http://somewhere/SarahJones http://www.w3.org/2001/vcard-rdf/3.0#Family Jones
# http://somewhere/SarahJones http://www.w3.org/2001/vcard-rdf/3.0#FN Sarah Jones
# http://somewhere/MattJones http://www.w3.org/2001/vcard-rdf/3.0#FN Matt Jones
# http://somewhere/SarahJones http://xmlns.com/foaf/0.1/email sJones@somewhere.com
# http://somewhere/JohnSmith http://www.w3.org/2001/vcard-rdf/3.0#Family Smith
# http://somewhere/JohnSmith http://www.w3.org/2001/vcard-rdf/3.0#Given John
# http://somewhere/MattJones http://www.w3.org/2001/vcard-rdf/3.0#Family Jones
# http://somewhere/MattJones http://xmlns.com/foaf/0.1/knows http://somewhere/JaneSmith
# http://somewhere/SarahJones http://www.w3.org/2001/vcard-rdf/3.0#Given Sarah

# %%
g.serialize("example1.ttl", format="ttl")
# Out:
# <Graph identifier=Nfc2168ada8f0445ab573b187150a91d2 (<class 'rdflib.graph.Graph'>)>

# %%
print(g.serialize(format="ttl"))
# Out:
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix vcard: <http://www.w3.org/2001/vcard-rdf/3.0#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://somewhere/JohnSmith> vcard:FN "John Smith"^^xsd:string ;
#     vcard:Family "Smith"^^xsd:string ;
#     vcard:Given "John"^^xsd:string .
#
# <http://somewhere/MattJones> vcard:FN "Matt Jones"^^xsd:string ;
#     vcard:Family "Jones"^^xsd:string ;
#     vcard:Given "Matt"^^xsd:string ;
#     foaf:knows <http://somewhere/JaneSmith> .
#
# <http://somewhere/SarahJones> vcard:FN "Sarah Jones"^^xsd:string ;
#     vcard:Family "Jones"^^xsd:string ;
#     vcard:Given "Sarah"^^xsd:string ;
#     foaf:email "sJones@somewhere.com"^^xsd:string .

# %%
print(g.serialize(format="xml"))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <rdf:RDF
#    xmlns:foaf="http://xmlns.com/foaf/0.1/"
#    xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#    xmlns:vcard="http://www.w3.org/2001/vcard-rdf/3.0#"
# >
#   <rdf:Description rdf:about="http://somewhere/JohnSmith">
#     <vcard:FN rdf:datatype="http://www.w3.org/2001/XMLSchema#string">John Smith</vcard:FN>
#     <vcard:Given rdf:datatype="http://www.w3.org/2001/XMLSchema#string">John</vcard:Given>
#     <vcard:Family rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Smith</vcard:Family>
#   </rdf:Description>
#   <rdf:Description rdf:about="http://somewhere/MattJones">
#     <vcard:FN rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Matt Jones</vcard:FN>
#     <vcard:Given rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Matt</vcard:Given>
#     <vcard:Family rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Jones</vcard:Family>
#     <foaf:knows rdf:resource="http://somewhere/JaneSmith"/>
# ...

# %% [markdown]
# # **Task 01: Reading and writing RDF files** (order the code in this section)

# %% [markdown]
# Spanish: Para leer y escribir ficheros que contienen tripletas en RDFlib empleamos dos métodos de la librería: parse y serialize. Podemos añadir tripletas a nuestro grafo empleando parse, que leerá el recurso proporcionado. Debemos además indicarle el formato si este no puede ser inferido. El recurso puede ser local o remoto, como en nuestro caso. El resultado es el mismo. Podemos añadir todos los datos que queramos a nuestro grafo, los datos simplemente se irán fusionando.
#
# English: To read and write RDF files that contain triplets we employ two methods from the library: parse and serialize. We can add triplets to our graph using parse, which will read the specified resource. We must also specify the format if it cannot be inferred. The resource can be local or remote, as in our case. The result is the same. We can add as much data as we want to our graph, and the data will simple be merged together.

# %% [markdown]
# Spanish:  Ahora podemos comprobar el resultado volcando las tripletas de forma sencilla.
#
# English: We can now check the result by simply outputting the triplets.

# %% [markdown]
# Spanish: Ahora podemos ver la operación inversa, serializando estos datos a algún formato que nos lo permita. Este proceso también nos permite una conversión sencilla entre formatos. Hacer primero en ttl y luego en xml.
#
# English: We can now look at the reverse process: serialising this data into a format that allows us to do so. This process also enables us to convert easily between formats. First in TTL, then in XML.

# %% [markdown]
# Spanish: También podemos guardar el resultado serializado en un fichero, puedes ver este fichero resultante en el panel izquierdo.
#
# English: We can also save the serialised result to a file; you can view this resulting file in the left-hand pane.

# %% [markdown]
# # **Task 01: Do the following exercises**

# %% [markdown]
# Spanish: Importar rdf/example1b.rdf
#
# English: Import rdf/example1b.rdf

# %%
from rdflib import Graph
g = Graph()
g.parse(github_storage+"/rdf/example1b.rdf", format="json-ld")
# Out:
# <Graph identifier=Ncb841f5cb5534b3c9f1e3eef569a3edb (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Spanish: Leer el grafo en formato json-ld
#
# English: Read the result in json-ld format

# %%
print(g.serialize(format="json-ld"))
# Out:
# [
#   {
#     "@id": "http://somewhere/RebeccaBrown",
#     "http://www.w3.org/2001/vcard-rdf/3.0#FN": [
#       {
#         "@type": "http://www.w3.org/2001/XMLSchema#string",
#         "@value": "Rebecca Brown"
#       }
#     ],
#     "http://www.w3.org/2001/vcard-rdf/3.0#Family": [
#       {
#         "@type": "http://www.w3.org/2001/XMLSchema#string",
#         "@value": "Brown"
#       }
#     ],
#     "http://www.w3.org/2001/vcard-rdf/3.0#Given": [
#       {
#         "@type": "http://www.w3.org/2001/XMLSchema#string",
#         "@value": "Rebecca"
#       }
#     ],
#     "http://xmlns.com/foaf/0.1/email": [
#       {
#         "@type": "http://www.w3.org/2001/XMLSchema#string",
#         "@value": "rBrown@somewhere.com"
#       }
#     ],
#     "http://xmlns.com/foaf/0.1/knows": [
#       {
#         "@id": "http://somewhere/JaneSmith"
#       }
#     ]
#   },
#   {
#     "@id": "http://somewhere/JaneSmith",
#     "http://www.w3.org/2001/vcard-rdf/3.0#FN": [
#       {
# ...

# %% [markdown]
# Spanish: Mostrar por pantalla cuántas tripletas tiene el grafo
#
# English: Print how many triples the graph contains

# %%
print(len(g))
# Out:
# 13

# %% [markdown]
# Spanish: Guardar el grafo en un fichero example1b.nt en formato N-Triples y abrirlo en el panel izquierdo
#
# English: Save the graph to example1b.nt using N-Triples and open it in the left-hand pane

# %%
g.serialize("example1b.nt",format="nt")
# Out:
# /usr/local/lib/python3.13/dist-packages/rdflib/plugins/serializers/nt.py:39: UserWarning: NTSerializer always uses UTF-8 encoding. Given encoding was: None
#   warnings.warn(
# <Graph identifier=Ncb841f5cb5534b3c9f1e3eef569a3edb (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Spanish: Convertir rdf/example2.rdf de RDF/XML a Turtle sin pasar por disco
#
# English: Convert rdf/example2.rdf from RDF/XML to Turtle without writing to disk

# %%
from rdflib import Graph
g2 = Graph()
g2.parse(github_storage+"/rdf/example2.rdf", format="xml")
print(g2.serialize(format="ttl"))
# Out:
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix vcard: <http://www.w3.org/2001/vcard-rdf/3.0#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://somewhere/MattJones> vcard:FN "Matt Jones"^^xsd:string ;
#     vcard:Family "Jones"^^xsd:string ;
#     vcard:Given "Matt"^^xsd:string ;
#     foaf:knows <http://somewhere/JaneSmith> .
